# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import os
path = os.getcwd()

path
# Out:
# '/Users/ninadamaso/code/ninadamaso/Demand-supply-analysis-and-prediction/Regression'

# %% [markdown]
# ## Dataframe

# %%
df = pd.read_csv("../DF/grand_master_report.csv")

# %%
df.head()
# Out:
#   Day\nDate DayoftheWeek\n  TotalSupply  MealsSaved SavedRatio  \
# 0  19.02.22       Saturday        10160        7411     72,94%
# 1  18.02.22         Friday        11705        7900     67,49%
# 2  17.02.22       Thursday        11756        7819     66,51%
# 3  16.02.22      Wednesday        11756        7925     67,41%
# 4  15.02.22        Tuesday        11797        8079     68,48%
#
#   SavedRatioEx.Manufacturer  DeclaredSupply  AddedSupply  SubtractedSupply  \
# 0                    73,38%            9554         1836              -955
# 1                    67,99%           11134         2031             -1221
# 2                    67,46%           10980         2141             -1151
# 3                    67,93%           10900         2152             -1069
# 4                    69,75%           10927         2164             -1081
#
#    PaidMeals  ...  SupplyingStoresManufacturer  NewSavingStoresManufacturer  \
# 0       7387  ...                           59                            0
# 1       7885  ...                          105                            0
# 2       7798  ...                           97                            0
# 3       7910  ...                          114                            0
# 4       8055  ...                          105                            0
#
#   NewSupplyingStoresManufacturer SavingStoresManufacturer  \
# 0                              0                       53
# 1                              0                       92
# 2                              0                       81
# 3                              0                      102
# 4                              0                       90
#
#   ChurnedStoresManufacturer NotSupplyingStoresManufacturer  \
# 0                         0                            341
# 1                         0                            295
# 2                         0                            303
# 3                         0                            285
# 4                         0                            294
#
#    SupplyingStoresLostManufacturer  ResupplyingStoresManufacturer  \
# 0                               60                             14
# 1                               18                             26
# 2                               33                             16
# 3                               22                             31
# 4                               14                             31
#
#    Avg.MealsSavedperPayingUser  ActiveUsers
# 0                         1,71        46326
# 1                         1,32        48647
# 2                         1,28        50662
# 3                         1,29        51943
# 4                         1,26        52472
#
# [5 rows x 45 columns]

# %%
manufacturer_columns=[col for col in df.columns.to_list() if col.endswith('Manufacturer')]
df.drop(columns=manufacturer_columns,inplace=True)
df
# Out:
#     Day\nDate DayoftheWeek\n  TotalSupply  MealsSaved SavedRatio  \
# 0    19.02.22       Saturday        10160        7411     72,94%
# 1    18.02.22         Friday        11705        7900     67,49%
# 2    17.02.22       Thursday        11756        7819     66,51%
# 3    16.02.22      Wednesday        11756        7925     67,41%
# 4    15.02.22        Tuesday        11797        8079     68,48%
# ..        ...            ...          ...         ...        ...
# 495  12.10.20         Monday         7215        5169     71,64%
# 496  11.10.20         Sunday         3074        2329     75,76%
# 497  10.10.20       Saturday         6757        4961     73,42%
# 498  09.10.20         Friday         7934        5542     69,85%
# 499  08.10.20       Thursday         7514        5182     68,96%
#
#      DeclaredSupply  AddedSupply  SubtractedSupply  PaidMeals  RefundedMeals  \
# 0              9554         1836              -955       7387             24
# 1             11134         2031             -1221       7885             15
# 2             10980         2141             -1151       7798             19
# 3             10900         2152             -1069       7910             14
# 4             10927         2164             -1081       8055             24
# ..              ...          ...               ...        ...            ...
# 495            6574         1277              -527       5140             27
# 496            2785          597              -229       2306             22
# 497            5858         1451              -401       4931             27
# 498            7208         1466              -598       5509             31
# 499            6997         1255              -592       5156             26
#
#      ...  ClosedStores ChurnedStores NotSupplyingStores SupplyingStoresLost  \
# 0    ...           169             0               2347                 769
# 1    ...           186             1               1898                 293
# 2    ...           176             2               1929                 293
# 3    ...           169             5               1940                 300
# 4    ...           175             3               1957                 237
# ..   ...           ...           ...                ...                 ...
# 495  ...            81             0               1448                 125
# 496  ...            78             0               2718                1171
# 497  ...            89             0               1597                 533
# 498  ...            87             0               1204                 151
# 499  ...            88             2               1243                 156
#
#     NewSavingIndependentStores  NewSavingKeyAccountStores  ResupplyingStores  \
# 0                            2                          1                318
# 1                            0                          1                322
# 2                            3                          1                300
# 3                            4                          1                313
# 4                            4                          1                504
# ..                         ...                        ...                ...
# 495                          3                         12               1380
# 496                          0                          0                 72
# 497                          2                          0                138
# 498                          2                          0                188
# 499                          2                          0                161
#
#      NewInboundLeads  Avg.MealsSavedperPayingUser  ActiveUsers
# 0                  3                         1,71        46326
# 1                  9                         1,32        48647
# 2                  2                         1,28        50662
# 3                  4                         1,29        51943
# 4                  3                         1,26        52472
# ..               ...                          ...          ...
# 495                5                         1,25        35724
# 496                3                         0,88        32239
# 497                2                         1,60        34595
# 498                3                         1,37        34784
# 499                4                         1,24        47527
#
# [500 rows x 34 columns]

# %%
df['Day\nDate'] = pd.to_datetime(df['Day\nDate'], format='%d.%m.%y')

# %%
df['m_y'] = df['Day\nDate'].dt.strftime('%m.%Y')

# %%
df['Day\nDate'] = pd.to_datetime(df['Day\nDate'], format='%d.%m.%y')

# %%
df
# Out:
#      Day\nDate DayoftheWeek\n  TotalSupply  MealsSaved SavedRatio  \
# 0   2022-02-19       Saturday        10160        7411     72,94%
# 1   2022-02-18         Friday        11705        7900     67,49%
# 2   2022-02-17       Thursday        11756        7819     66,51%
# 3   2022-02-16      Wednesday        11756        7925     67,41%
# 4   2022-02-15        Tuesday        11797        8079     68,48%
# ..         ...            ...          ...         ...        ...
# 495 2020-10-12         Monday         7215        5169     71,64%
# 496 2020-10-11         Sunday         3074        2329     75,76%
# 497 2020-10-10       Saturday         6757        4961     73,42%
# 498 2020-10-09         Friday         7934        5542     69,85%
# 499 2020-10-08       Thursday         7514        5182     68,96%
#
#      DeclaredSupply  AddedSupply  SubtractedSupply  PaidMeals  RefundedMeals  \
# 0              9554         1836              -955       7387             24
# 1             11134         2031             -1221       7885             15
# 2             10980         2141             -1151       7798             19
# 3             10900         2152             -1069       7910             14
# 4             10927         2164             -1081       8055             24
# ..              ...          ...               ...        ...            ...
# 495            6574         1277              -527       5140             27
# 496            2785          597              -229       2306             22
# 497            5858         1451              -401       4931             27
# 498            7208         1466              -598       5509             31
# 499            6997         1255              -592       5156             26
#
#      ...  ChurnedStores NotSupplyingStores SupplyingStoresLost  \
# 0    ...              0               2347                 769
# 1    ...              1               1898                 293
# 2    ...              2               1929                 293
# 3    ...              5               1940                 300
# 4    ...              3               1957                 237
# ..   ...            ...                ...                 ...
# 495  ...              0               1448                 125
# 496  ...              0               2718                1171
# 497  ...              0               1597                 533
# 498  ...              0               1204                 151
# 499  ...              2               1243                 156
#
#     NewSavingIndependentStores NewSavingKeyAccountStores  ResupplyingStores  \
# 0                            2                         1                318
# 1                            0                         1                322
# 2                            3                         1                300
# 3                            4                         1                313
# 4                            4                         1                504
# ..                         ...                       ...                ...
# 495                          3                        12               1380
# 496                          0                         0                 72
# 497                          2                         0                138
# 498                          2                         0                188
# 499                          2                         0                161
#
#      NewInboundLeads  Avg.MealsSavedperPayingUser  ActiveUsers      m_y
# 0                  3                         1,71        46326  02.2022
# 1                  9                         1,32        48647  02.2022
# 2                  2                         1,28        50662  02.2022
# 3                  4                         1,29        51943  02.2022
# 4                  3                         1,26        52472  02.2022
# ..               ...                          ...          ...      ...
# 495                5                         1,25        35724  10.2020
# 496                3                         0,88        32239  10.2020
# 497                2                         1,60        34595  10.2020
# 498                3                         1,37        34784  10.2020
# 499                4                         1,24        47527  10.2020
#
# [500 rows x 35 columns]

# %%
df["month_year"] = df['Day\nDate'].dt.to_period('M')

# %%
df["year"] = df['Day\nDate'].dt.to_period('Y')

# %%
df = df.sort_values(by='Day\nDate', ascending=True)
df
# Out:
#      Day\nDate DayoftheWeek\n  TotalSupply  MealsSaved SavedRatio  \
# 499 2020-10-08       Thursday         7514        5182     68,96%
# 498 2020-10-09         Friday         7934        5542     69,85%
# 497 2020-10-10       Saturday         6757        4961     73,42%
# 496 2020-10-11         Sunday         3074        2329     75,76%
# 495 2020-10-12         Monday         7215        5169     71,64%
# ..         ...            ...          ...         ...        ...
# 4   2022-02-15        Tuesday        11797        8079     68,48%
# 3   2022-02-16      Wednesday        11756        7925     67,41%
# 2   2022-02-17       Thursday        11756        7819     66,51%
# 1   2022-02-18         Friday        11705        7900     67,49%
# 0   2022-02-19       Saturday        10160        7411     72,94%
#
#      DeclaredSupply  AddedSupply  SubtractedSupply  PaidMeals  RefundedMeals  \
# 499            6997         1255              -592       5156             26
# 498            7208         1466              -598       5509             31
# 497            5858         1451              -401       4931             27
# 496            2785          597              -229       2306             22
# 495            6574         1277              -527       5140             27
# ..              ...          ...               ...        ...            ...
# 4             10927         2164             -1081       8055             24
# 3             10900         2152             -1069       7910             14
# 2             10980         2141             -1151       7798             19
# 1             11134         2031             -1221       7885             15
# 0              9554         1836              -955       7387             24
#
#      ...  SupplyingStoresLost NewSavingIndependentStores  \
# 499  ...                  156                          2
# 498  ...                  151                          2
# 497  ...                  533                          2
# 496  ...                 1171                          0
# 495  ...                  125                          3
# ..   ...                  ...                        ...
# 4    ...                  237                          4
# 3    ...                  300                          4
# 2    ...                  293                          3
# 1    ...                  293                          0
# 0    ...                  769                          2
#
#     NewSavingKeyAccountStores ResupplyingStores NewInboundLeads  \
# 499                         0               161               4
# 498                         0               188               3
# 497                         0               138               2
# 496                         0                72               3
# 495                        12              1380               5
# ..                        ...               ...             ...
# 4                           1               504               3
# 3                           1               313               4
# 2                           1               300               2
# 1                           1               322               9
# 0                           1               318               3
#
#      Avg.MealsSavedperPayingUser  ActiveUsers      m_y  month_year  year
# 499                         1,24        47527  10.2020     2020-10  2020
# 498                         1,37        34784  10.2020     2020-10  2020
# 497                         1,60        34595  10.2020     2020-10  2020
# 496                         0,88        32239  10.2020     2020-10  2020
# 495                         1,25        35724  10.2020     2020-10  2020
# ..                           ...          ...      ...         ...   ...
# 4                           1,26        52472  02.2022     2022-02  2022
# 3                           1,29        51943  02.2022     2022-02  2022
# 2                           1,28        50662  02.2022     2022-02  2022
# 1                           1,32        48647  02.2022     2022-02  2022
# 0                           1,71        46326  02.2022     2022-02  2022
#
# [500 rows x 37 columns]

# %%
df['mm'] = pd.to_datetime(df['Day\nDate']).dt.month
df
# Out:
#      Day\nDate DayoftheWeek\n  TotalSupply  MealsSaved SavedRatio  \
# 499 2020-10-08       Thursday         7514        5182     68,96%
# 498 2020-10-09         Friday         7934        5542     69,85%
# 497 2020-10-10       Saturday         6757        4961     73,42%
# 496 2020-10-11         Sunday         3074        2329     75,76%
# 495 2020-10-12         Monday         7215        5169     71,64%
# ..         ...            ...          ...         ...        ...
# 4   2022-02-15        Tuesday        11797        8079     68,48%
# 3   2022-02-16      Wednesday        11756        7925     67,41%
# 2   2022-02-17       Thursday        11756        7819     66,51%
# 1   2022-02-18         Friday        11705        7900     67,49%
# 0   2022-02-19       Saturday        10160        7411     72,94%
#
#      DeclaredSupply  AddedSupply  SubtractedSupply  PaidMeals  RefundedMeals  \
# 499            6997         1255              -592       5156             26
# 498            7208         1466              -598       5509             31
# 497            5858         1451              -401       4931             27
# 496            2785          597              -229       2306             22
# 495            6574         1277              -527       5140             27
# ..              ...          ...               ...        ...            ...
# 4             10927         2164             -1081       8055             24
# 3             10900         2152             -1069       7910             14
# 2             10980         2141             -1151       7798             19
# 1             11134         2031             -1221       7885             15
# 0              9554         1836              -955       7387             24
#
#      ...  NewSavingIndependentStores NewSavingKeyAccountStores  \
# 499  ...                           2                         0
# 498  ...                           2                         0
# 497  ...                           2                         0
# 496  ...                           0                         0
# 495  ...                           3                        12
# ..   ...                         ...                       ...
# 4    ...                           4                         1
# 3    ...                           4                         1
# 2    ...                           3                         1
# 1    ...                           0                         1
# 0    ...                           2                         1
#
#     ResupplyingStores NewInboundLeads Avg.MealsSavedperPayingUser  \
# 499               161               4                        1,24
# 498               188               3                        1,37
# 497               138               2                        1,60
# 496                72               3                        0,88
# 495              1380               5                        1,25
# ..                ...             ...                         ...
# 4                 504               3                        1,26
# 3                 313               4                        1,29
# 2                 300               2                        1,28
# 1                 322               9                        1,32
# 0                 318               3                        1,71
#
#      ActiveUsers      m_y  month_year  year  mm
# 499        47527  10.2020     2020-10  2020  10
# 498        34784  10.2020     2020-10  2020  10
# 497        34595  10.2020     2020-10  2020  10
# 496        32239  10.2020     2020-10  2020  10
# 495        35724  10.2020     2020-10  2020  10
# ..           ...      ...         ...   ...  ..
# 4          52472  02.2022     2022-02  2022   2
# 3          51943  02.2022     2022-02  2022   2
# 2          50662  02.2022     2022-02  2022   2
# 1          48647  02.2022     2022-02  2022   2
# 0          46326  02.2022     2022-02  2022   2
#
# [500 rows x 38 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500 entries, 499 to 0
# Data columns (total 38 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Day
# Date                     500 non-null    datetime64[ns]
#  1   DayoftheWeek
#                 500 non-null    object
#  2   TotalSupply                  500 non-null    int64
#  3   MealsSaved                   500 non-null    int64
#  4   SavedRatio                   500 non-null    object
#  5   DeclaredSupply               500 non-null    int64
#  6   AddedSupply                  500 non-null    int64
#  7   SubtractedSupply             500 non-null    int64
#  8   PaidMeals                    500 non-null    int64
#  9   RefundedMeals                500 non-null    int64
#  10  FreeMeals                    500 non-null    int64
#  11  RefundRatio                  500 non-null    object
#  12  StoreCancellationRatio       500 non-null    object
#  13  ConsumerCancellationRatio    500 non-null    object
#  14  AverageRatingOverall         500 non-null    object
#  15  NewRegisteredUsers           500 non-null    int64
#  16  All-TimeRegisteredUsers      500 non-null    int64
#  17  PayingUsers                  500 non-null    int64
#  18  NewPayingUsers               500 non-null    int64
#  19  All-TimePayingUsers          500 non-null    int64
#  20  SupplyingStores              500 non-null    int64
#  21  NewSavingStores              500 non-null    int64
#  22  NewSupplyingStores           500 non-null    int64
#  23  SavingStores                 500 non-null    int64
#  24  ClosedStores                 500 non-null    int64
#  25  ChurnedStores                500 non-null    int64
#  26  NotSupplyingStores           500 non-null    int64
#  27  SupplyingStoresLost          500 non-null    int64
#  28  NewSavingIndependentStores   500 non-null    int64
#  29  NewSavingKeyAccountStores    500 non-null    int64
#  30  ResupplyingStores            500 non-null    int64
#  31  NewInboundLeads              500 non-null    int64
#  32  Avg.MealsSavedperPayingUser  500 non-null    object
#  33  ActiveUsers                  500 non-null    int64
#  34  m_y                          500 non-null    object
#  35  month_year                   500 non-null    period[M]
#  36  year                         500 non-null    period[A-DEC]
#  37  mm                           500 non-null    int64
# dtypes: datetime64[ns](1), int64(27), object(8), period[A-DEC](1), period[M](1)
# memory usage: 152.3+ KB

# %% [markdown]
# ## Visualisation

# %%
plt.figure(figsize=(28, 6))

sns.lineplot(data=df, x="Day\nDate", y="NewPayingUsers")
sns.lineplot(data=df, x="Day\nDate", y="PaidMeals")
# Out:
# <AxesSubplot:xlabel='Day\nDate', ylabel='NewPayingUsers'>

# %%
plt.figure(figsize=(28, 6))

sns.lineplot(data=df, x="Day\nDate", y="AddedSupply")
sns.lineplot(data=df, x="Day\nDate", y="SubtractedSupply")
# Out:
# <AxesSubplot:xlabel='Day\nDate', ylabel='AddedSupply'>

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(data=df, x="Day\nDate", y="ActiveUsers")
# Out:
# <AxesSubplot:xlabel='Day\nDate', ylabel='ActiveUsers'>

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(data=df, x="Day\nDate", y="DeclaredSupply")
# Out:
# <AxesSubplot:xlabel='Day\nDate', ylabel='DeclaredSupply'>

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(data=df, x="m_y", y="DeclaredSupply")
# Out:
# <AxesSubplot:xlabel='m_y', ylabel='DeclaredSupply'>

# %%
df['month_year'].value_counts()
# Out:
# 2022-01    31
# 2020-12    31
# 2021-01    31
# 2021-03    31
# 2021-05    31
# 2021-07    31
# 2021-08    31
# 2021-10    31
# 2021-12    31
# 2021-06    30
# 2021-04    30
# 2020-11    30
# 2021-09    30
# 2021-11    30
# 2021-02    28
# 2020-10    24
# 2022-02    19
# Freq: M, Name: month_year, dtype: int64

# %%
plt.figure(figsize=(28, 6))

sns.lineplot(data=df, x="Day\nDate", y="ActiveUsers")
# Out:
# <AxesSubplot:xlabel='Day\nDate', ylabel='ActiveUsers'>

# %%
plt.figure(figsize=(28,15))
sns.heatmap(df.corr(), cmap='coolwarm', annot = True, annot_kws={"size": 12})
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(28, 15))

sns.lineplot(data=df, x="m_y", y="ActiveUsers")
sns.lineplot(data=df, x="m_y", y="MealsSaved")
# Out:
# <AxesSubplot:xlabel='m_y', ylabel='ActiveUsers'>

# %%
plt.figure(figsize=(28, 10))

sns.scatterplot(data=df, x="PayingUsers", y="MealsSaved", hue="MealsSaved")
# Out:
# <AxesSubplot:xlabel='PayingUsers', ylabel='MealsSaved'>

# %%
plt.figure(figsize=(28, 10))

sns.scatterplot(data=df, x="NewPayingUsers", y="MealsSaved", hue="MealsSaved", sizes=(200, 80))
# Out:
# <AxesSubplot:xlabel='NewPayingUsers', ylabel='MealsSaved'>

# %%
plt.figure(figsize=(28, 10))

sns.scatterplot(data=df, x="ActiveUsers", y="PayingUsers", hue="All-TimePayingUsers")
# Out:
# <AxesSubplot:xlabel='ActiveUsers', ylabel='PayingUsers'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500 entries, 499 to 0
# Data columns (total 38 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Day
# Date                     500 non-null    datetime64[ns]
#  1   DayoftheWeek
#                 500 non-null    object
#  2   TotalSupply                  500 non-null    int64
#  3   MealsSaved                   500 non-null    int64
#  4   SavedRatio                   500 non-null    object
#  5   DeclaredSupply               500 non-null    int64
#  6   AddedSupply                  500 non-null    int64
#  7   SubtractedSupply             500 non-null    int64
#  8   PaidMeals                    500 non-null    int64
#  9   RefundedMeals                500 non-null    int64
#  10  FreeMeals                    500 non-null    int64
#  11  RefundRatio                  500 non-null    object
#  12  StoreCancellationRatio       500 non-null    object
#  13  ConsumerCancellationRatio    500 non-null    object
#  14  AverageRatingOverall         500 non-null    object
#  15  NewRegisteredUsers           500 non-null    int64
#  16  All-TimeRegisteredUsers      500 non-null    int64
#  17  PayingUsers                  500 non-null    int64
#  18  NewPayingUsers               500 non-null    int64
#  19  All-TimePayingUsers          500 non-null    int64
#  20  SupplyingStores              500 non-null    int64
#  21  NewSavingStores              500 non-null    int64
#  22  NewSupplyingStores           500 non-null    int64
#  23  SavingStores                 500 non-null    int64
#  24  ClosedStores                 500 non-null    int64
#  25  ChurnedStores                500 non-null    int64
#  26  NotSupplyingStores           500 non-null    int64
#  27  SupplyingStoresLost          500 non-null    int64
#  28  NewSavingIndependentStores   500 non-null    int64
#  29  NewSavingKeyAccountStores    500 non-null    int64
#  30  ResupplyingStores            500 non-null    int64
#  31  NewInboundLeads              500 non-null    int64
#  32  Avg.MealsSavedperPayingUser  500 non-null    object
#  33  ActiveUsers                  500 non-null    int64
#  34  m_y                          500 non-null    object
#  35  month_year                   500 non-null    period[M]
#  36  year                         500 non-null    period[A-DEC]
#  37  mm                           500 non-null    int64
# dtypes: datetime64[ns](1), int64(27), object(8), period[A-DEC](1), period[M](1)
# memory usage: 168.5+ KB

# %%
plt.figure(figsize=(28, 6))


sns.boxplot(data=df, x="m_y", y="ActiveUsers")
# Out:
# <AxesSubplot:xlabel='m_y', ylabel='ActiveUsers'>

# %%
df.head()
# Out:
#      Day\nDate DayoftheWeek\n  TotalSupply  MealsSaved SavedRatio  \
# 499 2020-10-08       Thursday         7514        5182     68,96%
# 498 2020-10-09         Friday         7934        5542     69,85%
# 497 2020-10-10       Saturday         6757        4961     73,42%
# 496 2020-10-11         Sunday         3074        2329     75,76%
# 495 2020-10-12         Monday         7215        5169     71,64%
#
#      DeclaredSupply  AddedSupply  SubtractedSupply  PaidMeals  RefundedMeals  \
# 499            6997         1255              -592       5156             26
# 498            7208         1466              -598       5509             31
# 497            5858         1451              -401       4931             27
# 496            2785          597              -229       2306             22
# 495            6574         1277              -527       5140             27
#
#      ...  NewSavingIndependentStores NewSavingKeyAccountStores  \
# 499  ...                           2                         0
# 498  ...                           2                         0
# 497  ...                           2                         0
# 496  ...                           0                         0
# 495  ...                           3                        12
#
#     ResupplyingStores NewInboundLeads Avg.MealsSavedperPayingUser  \
# 499               161               4                        1,24
# 498               188               3                        1,37
# 497               138               2                        1,60
# 496                72               3                        0,88
# 495              1380               5                        1,25
#
#      ActiveUsers      m_y  month_year  year  mm
# 499        47527  10.2020     2020-10  2020  10
# 498        34784  10.2020     2020-10  2020  10
# 497        34595  10.2020     2020-10  2020  10
# 496        32239  10.2020     2020-10  2020  10
# 495        35724  10.2020     2020-10  2020  10
#
# [5 rows x 38 columns]

# %% [markdown]
# ## Prophet MealsSaved

# %%
dfp = pd.DataFrame(df, columns = ['Day\nDate', 'MealsSaved'])
dfp
# Out:
#      Day\nDate  MealsSaved
# 499 2020-10-08        5182
# 498 2020-10-09        5542
# 497 2020-10-10        4961
# 496 2020-10-11        2329
# 495 2020-10-12        5169
# ..         ...         ...
# 4   2022-02-15        8079
# 3   2022-02-16        7925
# 2   2022-02-17        7819
# 1   2022-02-18        7900
# 0   2022-02-19        7411
#
# [500 rows x 2 columns]

# %%
dfp.columns = ['ds', 'y']

dfp.head()
# Out:
#             ds     y
# 499 2020-10-08  5182
# 498 2020-10-09  5542
# 497 2020-10-10  4961
# 496 2020-10-11  2329
# 495 2020-10-12  5169

# %%
dfp['ds'] = pd.to_datetime(dfp['ds'])
dfp
# Out:
#             ds     y
# 499 2020-10-08  5182
# 498 2020-10-09  5542
# 497 2020-10-10  4961
# 496 2020-10-11  2329
# 495 2020-10-12  5169
# ..         ...   ...
# 4   2022-02-15  8079
# 3   2022-02-16  7925
# 2   2022-02-17  7819
# 1   2022-02-18  7900
# 0   2022-02-19  7411
#
# [500 rows x 2 columns]

# %%
plt.figure(figsize=(12, 8))
plt.grid(linestyle='-.')

plt.plot(dfp['ds'], dfp['y'], 'b')
plt.show()

# %%
from fbprophet import Prophet
train = dfp.iloc[:440]
test = dfp.iloc[440:]
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/sk/356yz4gx0c169x5ft8052vkc0000gn/T/ipykernel_33639/1961952913.py in <module>
# ----> 1 from fbprophet import Prophet
#       2 train = dfp.iloc[:440]
#       3 test = dfp.iloc[440:]
#
# ModuleNotFoundError: No module named 'fbprophet'

# %%
train.shape, test.shape

# %%
train

# %%
model = Prophet(seasonality_mode='multiplicative', interval_width=0.95, yearly_seasonality=True, weekly_seasonality=True)
model.fit(train)

# %%
horizon = 36
future = model.make_future_dataframe(periods=horizon)
forecast = model.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()

# %%
ax = model.plot(forecast);

# %%
plt.figure(figsize=(15, 8))
plt.plot(train['ds'], train['y'], label="Train")
plt.plot(test['ds'], test['y'], label="Test")
plt.plot(forecast[-horizon:]['ds'], forecast[-horizon:]['yhat'], label="predictions")
plt.legend(loc="best")
plt.show()

# %%
model.plot_components(forecast);

# %%
800 days total dataset
initial = 624 == size of train dataset
horizon = 20 == size to be forecasted
period = 10 (default = 1/2 of horizon) == spacing between cutoff dates as incremental

440
initial = 440
horizon = 20
period = 10

# %%
from fbprophet.diagnostics import cross_validation
from fbprophet.diagnostics import performance_metrics

cv_results = cross_validation(model=model, initial="343 days", horizon='30 days', period='7 days')

# %%
cv_results

# %%
dfp_p = performance_metrics(cv_results)
dfp_p

# %%
from fbprophet.plot import plot_cross_validation_metric
plot_cross_validation_metric(cv_results, metric='mse');

# %% [markdown]
# ## Prophet NewRegisteredUsers

# %% [markdown]
# ### Df

# %%
dfp_nu = pd.DataFrame(df, columns = ['Day\nDate', 'NewRegisteredUsers'])
dfp_nu

# %%
dfp_nu.columns = ['ds', 'y']

dfp_nu.head()

# %%
dfp_nu['ds'] = pd.to_datetime(dfp_nu['ds'])
dfp_nu

# %%
plt.figure(figsize=(12, 8))
plt.grid(linestyle='-.')

plt.plot(dfp_nu['ds'], dfp_nu['y'], 'b')
plt.show()

# %%
train_nu = dfp_nu.iloc[:350]
test_nu = dfp_nu.iloc[350:]

# %%
train_nu.shape, test_nu.shape

# %%
model_nu = Prophet(seasonality_mode='multiplicative', interval_width=0.95, yearly_seasonality=True, weekly_seasonality=True)
model_nu.fit(train_nu)

# %%
horizon = 24
future = model_nu.make_future_dataframe(periods=horizon)
forecast = model_nu.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()

# %%
ax = model_nu.plot(forecast);

# %%
plt.figure(figsize=(15, 8))
plt.plot(train_nu['ds'], train_nu['y'], label="Train")
plt.plot(test_nu['ds'], test_nu['y'], label="Test")
plt.plot(forecast[-horizon:]['ds'], forecast[-horizon:]['yhat'], label="predictions")
plt.legend(loc="best")
plt.show()

# %%
model_nu.plot_components(forecast);

# %%
m = Prophet()
m.fit(dfp_nu)

# %%
future = m.make_future_dataframe(periods=365)
future.tail()

# %%
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()

# %%
forecast

# %%
import numpy as np
f_yhat = forecast["yhat"]
f_AU = f_yhat[350:500]


e_y = dfp_nu["y"]
e_AU = e_y[350:]

# %%
e_AU = e_AU.astype("float")

# %%
e_AU = np.array(e_AU.values.tolist())

# %%
expected_AU = e_AU
expected_AU

# %%
f_AU = np.array(f_AU.values.tolist())

# %%
forecast_AU = f_AU
forecast_AU

# %%
#np array beginning +350 days after 
#np array slize 150

# %%
fig1 = m.plot(forecast)

# %%
fig2 = m.plot_components(forecast)
fig2

# %% [markdown]
# ### Metrics

# %%
def forecast_accuracy(forecast, actual):
    mape = np.mean(np.abs(forecast_AU - expected_AU)/np.abs(expected_AU))  # MAPE
    me = np.mean(forecast_AU - expected_AU)             # ME
    mae = np.mean(np.abs(forecast_AU - expected_AU))    # MAE
    mpe = np.mean((forecast_AU - expected_AU)/expected_AU)   # MPE
    rmse = np.mean((forecast_AU - expected_AU)**2)**.5  # RMSE
    corr = np.corrcoef(forecast_AU, expected_AU)[0,1]   # corr
    mins = np.amin(np.hstack([forecast_AU[:,None], 
                              expected_AU[:,None]]), axis=1)
    maxs = np.amax(np.hstack([forecast_AU[:,None], 
                              expected_AU[:,None]]), axis=1)
    minmax = 1 - np.mean(mins/maxs)             # minmax                     
    return({'mape':mape, 'me':me, 'mae': mae, 
            'mpe': mpe, 'rmse':rmse, 
            'corr':corr, 'minmax':minmax})

forecast_accuracy(forecast_AU, expected_AU)

# %%
#yhat - predicted variable
#y - dependent variable

# %% [markdown]
# ### Cross_validation

# %%
cv_results_nu = cross_validation(model=model_nu, initial="150 days", horizon='60 days', period='30 days')

# %%
cv_results_nu

# %%
dfp_nu = performance_metrics(cv_results_nu)
dfp_nu

# %%
plot_cross_validation_metric(cv_results_nu, metric='mse');

# %% [markdown]
# ## Prophet PayingUsers

# %%
dfp_pu = pd.DataFrame(df, columns = ['Day\nDate', 'PayingUsers'])
dfp_pu

# %%
dfp_pu.columns = ['ds', 'y']
dfp_pu.head()

# %%
dfp_pu['ds'] = pd.to_datetime(dfp_pu['ds'])
dfp_pu

# %%
plt.figure(figsize=(12, 8))
plt.grid(linestyle='-.')

plt.plot(dfp_pu['ds'], dfp_pu['y'], 'b')
plt.show()

# %%
train_pu = dfp_pu.iloc[:350]
test_pu = dfp_pu.iloc[350:]

# %%
train_pu.shape, test_pu.shape

# %%
model_pu = Prophet(seasonality_mode='multiplicative', interval_width=0.95, yearly_seasonality=True, weekly_seasonality=True)
model_pu.fit(train_pu)

# %%
horizon = 24
future = model_pu.make_future_dataframe(periods=horizon)
forecast = model_pu.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()

# %%
ax = model_pu.plot(forecast_pu);

# %%
plt.figure(figsize=(15, 8))
plt.plot(train_pu['ds'], train_pu['y'], label="Train")
plt.plot(test_pu['ds'], test_pu['y'], label="Test")
plt.plot(forecast[-horizon:]['ds'], forecast[-horizon:]['yhat'], label="predictions")
plt.legend(loc="best")
plt.show()

# %%
model_pu.plot_components(forecast);

# %%
m_pu = Prophet()
m_pu.fit(dfp_pu)

# %%
future_pu = m_pu.make_future_dataframe(periods=365)
future_pu.tail()

# %%
forecast_pu = m_pu.predict(future_pu)
forecast_pu[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()

# %%
forecast_pu

# %%
import numpy as np
f_yhat_pu = forecast_pu["yhat"]
f_AU_pu = f_yhat_pu[350:500]


e_y_pu = dfp_pu["y"]
e_AU_pu = e_y_pu[350:]

# %%
e_AU_pu = np.array(e_AU_pu.values.tolist())

# %%
expected_AU_pu = e_AU_pu
expected_AU_pu

# %%
f_AU_pu = np.array(f_AU_pu.values.tolist())

# %%
forecast_AU_pu = f_AU_pu
forecast_AU_pu

# %%
fig2 = m_pu.plot(forecast_pu);

# %% [markdown]
# ### Metrics PayingUsers

# %%
def forecast_accuracy(forecast, actual):
    mape = np.mean(np.abs(forecast_AU_pu - expected_AU_pu)/np.abs(expected_AU_pu))  # MAPE
    me = np.mean(forecast_AU_pu - expected_AU_pu)             # ME
    mae = np.mean(np.abs(forecast_AU_pu - expected_AU_pu))    # MAE
    mpe = np.mean((forecast_AU_pu - expected_AU_pu)/expected_AU_pu)   # MPE
    rmse = np.mean((forecast_AU_pu - expected_AU_pu)**2)**.5  # RMSE
    corr = np.corrcoef(forecast_AU_pu, expected_AU_pu)[0,1]   # corr
    mins = np.amin(np.hstack([forecast_AU_pu[:,None], 
                              expected_AU_pu[:,None]]), axis=1)
    maxs = np.amax(np.hstack([forecast_AU_pu[:,None], 
                              expected_AU_pu[:,None]]), axis=1)
    minmax = 1 - np.mean(mins/maxs)             # minmax                     
    return({'mape':mape, 'me':me, 'mae': mae, 
            'mpe': mpe, 'rmse':rmse, 
            'corr':corr, 'minmax':minmax})

forecast_accuracy(forecast_AU_pu, expected_AU_pu)

# %% [markdown]
# ### Cross_validation

# %%
cv_results_pu = cross_validation(model=model_pu, initial="343 days", horizon='30 days', period='7 days')

# %%
cv_results_pu

# %%
dfp_pu = performance_metrics(cv_results_pu)
dfp_pu

# %%
plot_cross_validation_metric(cv_results_pu, metric='mse');

# %% [markdown]
# ## Prophet ActiveUsers

# %%
dfp_au = pd.DataFrame(df, columns = ['Day\nDate', 'ActiveUsers'])
dfp_au

# %%
dfp_au.columns = ['ds', 'y']
dfp_au.head()

# %%
dfp_au['ds'] = pd.to_datetime(dfp['ds'])
dfp_au

# %%
plt.figure(figsize=(12, 8))
plt.grid(linestyle='-.')

plt.plot(dfp_au['ds'], dfp_au['y'], 'b')
plt.show()

# %%
train_au = dfp_au.iloc[:350]
test_au = dfp_au.iloc[350:]

# %%
train_au.shape, test_au.shape

# %%
model_au = Prophet(seasonality_mode='multiplicative', interval_width=0.95, yearly_seasonality=True, weekly_seasonality=True)
model_au.fit(train_au)

# %%
horizon = 24
future = model_au.make_future_dataframe(periods=horizon)
forecast = model_au.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()

# %%
ax = model_au.plot(forecast);

# %%
plt.figure(figsize=(15, 8))
plt.plot(train_au['ds'], train_au['y'], label="Train")
plt.plot(test_au['ds'], test_au['y'], label="Test")
plt.plot(forecast[-horizon:]['ds'], forecast[-horizon:]['yhat'], label="predictions")
plt.legend(loc="best")
plt.show()

# %%
model_au.plot_components(forecast);

# %%
m_au = Prophet()
m_au.fit(dfp_au)

# %%
future_au = m_au.make_future_dataframe(periods=365)
future_au.tail()

# %%
forecast_au = m_au.predict(future_au)
forecast_au[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()

# %%
forecast_au

# %%
f_yhat_au = forecast_au["yhat"]
f_AU_au = f_yhat_au[350:500]


e_y_au = dfp_au["y"]
e_AU_au = e_y_au[350:]

# %%
e_AU_au = np.array(e_AU_au.values.tolist())

# %%
expected_AU_au = e_AU_au
expected_AU_au

# %%
f_AU_au = np.array(f_AU_au.values.tolist())

# %%
forecast_AU_au = f_AU_au
forecast_AU_au

# %%
fig2 = m_au.plot(forecast_au)

# %% [markdown]
# ### Metrics

# %%
def forecast_accuracy(forecast, actual):
    mape = np.mean(np.abs(forecast_AU_au - expected_AU_au)/np.abs(expected_AU_au))  # MAPE
    me = np.mean(forecast_AU_au - expected_AU_au)             # ME
    mae = np.mean(np.abs(forecast_AU_au - expected_AU_au))    # MAE
    mpe = np.mean((forecast_AU_au - expected_AU_au)/expected_AU_au)   # MPE
    rmse = np.mean((forecast_AU_au - expected_AU_au)**2)**.5  # RMSE
    corr = np.corrcoef(forecast_AU_au, expected_AU_au)[0,1]   # corr
    mins = np.amin(np.hstack([forecast_AU_au[:,None], 
                              expected_AU_au[:,None]]), axis=1)
    maxs = np.amax(np.hstack([forecast_AU_au[:,None], 
                              expected_AU_au[:,None]]), axis=1)
    minmax = 1 - np.mean(mins/maxs)             # minmax                     
    return({'mape':mape, 'me':me, 'mae': mae, 
            'mpe': mpe, 'rmse':rmse, 
            'corr':corr, 'minmax':minmax})

forecast_accuracy(forecast_AU_au, expected_AU_au)

# %%
cv_results_au = cross_validation(model=model_au, initial="343 days", horizon='30 days', period='7 days')

# %%
cv_results_au

# %%
dfp_au = performance_metrics(cv_results_au)
dfp_au

# %%
plot_cross_validation_metric(cv_results_au, metric='mse');

# %% [markdown]
# ## Prophet NewPayingUsers

# %%
dfp_npu = pd.DataFrame(df, columns = ['Day\nDate', 'NewPayingUsers'])
dfp_npu

# %%
dfp_npu.columns = ['ds', 'y']
dfp_npu.head()

# %%
dfp_npu['ds'] = pd.to_datetime(dfp_npu['ds'])
dfp_npu

# %%
plt.figure(figsize=(12, 8))
plt.grid(linestyle='-.')

plt.plot(dfp_npu['ds'], dfp_npu['y'], 'b')
plt.show()

# %%
train_npu = dfp_npu.iloc[:440]
test_npu = dfp_npu.iloc[440:]

# %%
train_npu.shape, test_npu.shape

# %%
model_npu = Prophet(seasonality_mode='multiplicative', interval_width=0.95, yearly_seasonality=True, weekly_seasonality=True)
model_npu.fit(train_npu)

# %%
horizon = 36
future = model_npu.make_future_dataframe(periods=horizon)
forecast = model_npu.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()

# %%
ax = model_npu.plot(forecast);

# %%
plt.figure(figsize=(15, 8))
plt.plot(train_npu['ds'], train_npu['y'], label="Train")
plt.plot(test_npu['ds'], test_npu['y'], label="Test")
plt.plot(forecast[-horizon:]['ds'], forecast[-horizon:]['yhat'], label="predictions")
plt.legend(loc="best")
plt.show()

# %%
model_npu.plot_components(forecast);

# %%
cv_results_npu = cross_validation(model=model_npu, initial="343 days", horizon='30 days', period='60 days')

# %%
cv_results_npu

# %%
dfp_npu = performance_metrics(cv_results_npu)
dfp_npu

# %%
plot_cross_validation_metric(cv_results_npu, metric='mse');

# %%
plot_cross_validation_metric(cv_results_npu, metric='mae');

# %%
plot_cross_validation_metric(cv_results_npu, metric='rmse');
